# %% [markdown]
# # 1. Import Libraries
#
# Import all the necessary libraries which will be used in this project.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.datasets import fetch_20newsgroups
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.decomposition import TruncatedSVD
import pandas as pd
import numpy as np
# !import nltk
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns
import re
# !pip install gensim
import gensim
import gensim.corpora as corpora
# !pip install pyLDAvis
import pyLDAvis
import pyLDAvis.lda_model as sklearn_lda
import pickle

# %% [markdown]
# # 2. Load data file
#
# Load the data file containing research papers into a dataframe called 'dataset'.

# %%
# load data file on codespaces
dataset = pd.read_csv(r'/workspaces/Automatic-Topic-Classification-Using-NLP-Topic-Models/Research Paper Topic Classification using NLP Techniques/Data/research_papers.csv', encoding='ISO-8859–1')

# load data file on local
# dataset = pd.read_csv(r'research_papers.csv', encoding='ISO-8859–1')

# %% [markdown]
# # 3. Clean Data
#
# I dropped the unnecessary columns like 'ID', 'Author','Year', 'Conference/Journal', and focused solely on the 'Abstract' and 'Conclusion' columns of each paper entry. For papers with no conclusions, I filled the empty cell with the text "No conclusion". Next, I merged the two columns 'Abstract' and 'Conclusion' to form a new column called 'PaperText'.

# %%
# remove the unecessary columns
dataset = dataset.drop(columns=['Id', 'Reference', 'Authors', 'Year', 'Conference/ Journal'], axis=1)

# fill in the empty cells
dataset = dataset.fillna('No conclusion')

# merge abstract and conclusion
dataset['Paper_Text'] = dataset["Abstract"] + dataset["Conclusion"]

# show first 5 records
dataset.head()
# Out:
#                                                Title  \
# 0  Design Considerations to Increase Block-based ...
# 1  Exploration of the use of auditory cues in cod...
# 2  Towards making block-based programming accessi...
# 3  Blocks4All: overcoming accessibility barriers ...
# 4  Making the Blockly Library Accessible via Touc...
#
#                                    Codes  \
# 0       BBL, DES, SR, KN, CE, CN, DT, CC
# 1     AP, CN, CC, BBL, DES, DT, ACUE, SM
# 2                 BBL, DES, DT, WAPP, PC
# 3  BBL, CH, CN, CC, SR, TS, SM, KDG, MSH
# 4               BBL, TS, SR, DES, CN, CE
#
#                                             Abstract  \
# 0  Block-based programming languages are a popula...
# 1  Visual programming languages are commonplace i...
# 2  Block-based programming environments are not a...
# 3  projects for pre-reader through grade 5 on the...
# 4  Block-based programming environments are a pop...
#
#                                           Conclusion  \
# 0  The initial version of accessible Blockly shou...
# 1                                      No conclusion
# 2                                      No conclusion
# 3  We conducted an evaluation of current blocks-b...
# 4  We present two interfaces which were designed ...
#
#                                           Paper_Text
# 0  Block-based programming languages are a popula...
# 1  Visual programming languages are commonplace i...
# 2  Block-based programming environments are not a...
# 3  projects for pre-reader through grade 5 on the...
# 4  Block-based programming environments are a pop...

# %% [markdown]
# # 4. Preprocess Data
#
# Tokenize each sentence into a list of words, remove punctuations, remove stopwords and words of length less than 3, and then lemmatize.

# %%
# function for lemmatization
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

# tokenization
tokenized_data = dataset['Paper_Text'].apply(lambda x: x.split()) 

# remove punctuation
tokenized_data = tokenized_data.apply(lambda x: [re.sub('[-,()\\.!?]', '', item) for item in x])

# turn to lowercase
tokenized_data = tokenized_data.apply(lambda x: [item.lower() for item in x])

# remove stop-words and short words
stop_words = stopwords.words('english')
stop_words.extend(['from','use', 'uses','user', 'users' 'well', 'study', 'survey', 'structjumper','think'])
tokenized_data = tokenized_data.apply(lambda x: [item for item in x if item not in stop_words and len(item)>3])

# lemmatize by calling lemmatization function
tokenized_data= tokenized_data.apply(lambda x: [get_lemma(item) for item in x])

# %% [markdown]
# # 5. Creating Bigrams and Trigrams
# Bigrams are two words frequently occurring together in the document. Trigrams are 3 words frequently occurring.
#
# Some examples in our corpus are: ‘visually_impaired’, ‘programming_language’, ‘block_based_programming’, 'programming environment' etc.
#
# Gensim’s Phrases model can build and implement the bigrams, trigrams, quadgrams and more. The two important arguments to Phrases are min_count and threshold. The higher the values of these param, the harder it is for words to be combined to bigrams

# %%
# build the bigram and trigram models
bigram = gensim.models.Phrases(tokenized_data, min_count=5, threshold=10) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[tokenized_data], threshold=10)  

# faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# see trigram example
print(trigram_mod[bigram_mod[tokenized_data[0]]])
# Out:
# ['blockbased_programming_language', 'popular', 'means', 'introduce', 'novice', 'specifically', 'child', 'programming', 'computational_thinking', 'concept', 'tool', 'broaden', 'participation', 'computing', 'time', 'blockbased_language', 'environment', 'obstacle', 'broadening', 'participation', 'many', 'user', 'disability', 'particular', 'blockbased_programming', 'environment', 'accessible', 'user', 'visually_impair', 'lack', 'access', 'impact', 'student', 'participate', 'computing', 'outreach', 'classroom', 'informal', 'setting', 'foster', 'interest', 'computing', 'paper', 'discus', 'accessibility', 'design', 'issue', 'blockbased_programming', 'environment', 'focus', 'programming', 'workflow', 'using', 'google', 'blockly', 'model', 'accessible', 'programming', 'workflow', 'present', 'works', 'alongside', 'conventional', 'mousedriven', 'workflow', 'typical', 'blockbased_programming', 'project', 'present', 'still', 'progressthe', 'initial', 'version', 'accessible', 'blockly', 'complete', 'winter', '2017', 'result', 'prior', 'audio', 'feedback', 'provide', 'early', 'feedback', 'interface', 'well', 'assess', 'impact', 'various', 'type', 'audio', 'feedback', 'modality', 'code_navigation', 'understanding', 'nest', 'feedback', 'use', 'implement', 'codebased', 'audio', 'feedback', 'code_navigation', 'conjunction', 'option', 'screen_reader', 'need', 'accessibility', 'feature', 'also', 'study', 'order', 'compare', 'usability', 'impact', 'user', 'without', 'sight', 'order', 'ascertain', 'value', 'found', 'sight_user', 'well', 'visually_impair', 'concern', 'include', 'verbosity', 'information', 'present', 'well', 'issue', 'young', 'user', 'often', 'user', 'blockbased', 'system', 'formal', 'study', 'allow', 'team', 'refine', 'system', 'provide', 'greater', 'access', 'user', 'provide', 'model', 'developer', 'blocklybased', 'system', 'blockbased', 'system', 'general', 'addition', 'blockbased_language', 'hybrid', 'text', 'blockbased_language', 'pencil_code', '[11]', 'also', 'potential', 'increase', 'accessibility', 'team', 'also', 'looking', 'apply', 'strategy', 'pencil_code', 'team', 'behind', 'pencil_code', 'codeorgs', 'block', 'language', 'integrate', 'accessibility', 'system', 'design', 'following', 'idea', 'discuss', 'change', 'interface', 'level', 'accommodation', 'deep', 'terms', 'redesign', 'feature', 'example', 'stride', 'framebased', 'editor', 'use', 'tool', 'greenfoot', '[12]', 'editor', 'enable', 'user', 'work', 'operations', 'construct', 'abstract', 'level', 'innovationand', 'others', 'like', 'help', 'increase', 'access', 'computer_science', 'student', 'disability', 'well', 'student', 'overall']

# %%
# define functions for creating bigrams and trigrams.
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

# %%
# form Bigrams
tokenized_data_bigrams = make_bigrams(tokenized_data)

 # form Trigrams
tokenized_data_trigrams = make_trigrams(tokenized_data)

# %%
# de-tokenization
detokenized_data = []
for i in range(len(dataset)):
    t = ' '.join(tokenized_data_trigrams[i])
    detokenized_data.append(t)
    
dataset['clean_text']= detokenized_data 
documents = dataset['clean_text']

# %% [markdown]
# # 6. Perform Exploratory Analysis
# To verify whether the preprocessing happened correctly, we’ll make a word cloud using the wordcloud package to get a visual representation of most common words. It is key to understanding the data and ensuring we are on the right track, and if any more preprocessing is necessary before training the model.

# %%
# import the wordcloud library
# !pip install wordcloud
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ','.join(list(documents.values))

# create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# generate a word cloud
wordcloud.generate(long_string)

# visualize the word cloud
wordcloud.to_image()
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from wordcloud) (1.26.3)
# Requirement already satisfied: pillow in /home/codespace/.local/lib/python3.10/site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in /home/codespace/.local/lib/python3.10/site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.1/511.1 kB 2.2 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python -m pip install --upgrade pip
# <PIL.Image.Image image mode=RGB size=400x200>

# %% [markdown]
# # 7. Create Document-Term Matrix
# This is the first step towards topic modeling. We need to represent each and every term and document as a vector.We will use sklearn's TfidfVectorizer to create a document-term matrix using only 1000 terms (words) from our corpus.

# %%
# set variables
no_terms = 1000

# NMF uses tf-idf Vectorizer
# initialise the tf-idf vectorizer with the English stop words
nmf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_terms, stop_words='english')
# fit and transform the text
nmf_matrix = nmf_vectorizer.fit_transform(documents)
# get features
nmf_feature_names = nmf_vectorizer.get_feature_names_out()

# LDA can only use raw term counts because it is a probabilistic graphical model
# initialise the count vectorizer with the English stop words
lda_vectorizer = CountVectorizer(max_df=0.5, min_df=2, max_features=no_terms, stop_words='english')
# fit and transform the text
lda_matrix = lda_vectorizer.fit_transform(documents)
# get features
lda_feature_names = lda_vectorizer.get_feature_names_out()

# LSA uses tf-idf also
# initialise the tf-idf vectorizer with the English stop words
lsa_vectorizer = TfidfVectorizer(max_df = 0.5, max_features= no_terms, stop_words='english', smooth_idf=True)
# fit and transform the text
lsa_matrix = lsa_vectorizer.fit_transform(documents)
# get features
lsa_feature_names = lsa_vectorizer.get_feature_names_out()

# %% [markdown]
# We’ll then plot the ten most frequent words based on the outcome of this operation (the list of document vectors) using the LDA model. As a check, these words should also occur in the word cloud.

# %%
sns.set_style('whitegrid')
# %matplotlib inline
# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names_out()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x=x_pos, y=counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()


# visualise the 10 most common words
plot_10_most_common_words(lda_matrix, lda_vectorizer)
# Out:
# /tmp/ipykernel_15952/2526253708.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x_pos, y=counts, palette='husl')

# %% [markdown]
# # 8. Apply Topic Model
# We will use the document-term matrix and decompose it into multiple matrices. We will use sklearn's LatentDirichletAllocation, to perform the task of matrix decomposition for our LDA Model,  TruncatedSVD for LSA, and  sklearn's NMF to perform the task of matrix decomposition for NMF. The number of topics can be specified by using the n_components parameter.

# %%
# set variables
no_topics = 10
no_top_words = 10

# custom function for displaying topics
def display_topic(model, feature_names, num_topics, no_top_words, model_name):    
    #the word ids obtained need to be reverse-mapped to the words so we can print the topic names.
    print("Model %s:" % model_name)
    word_dict = {};
    for i in range(num_topics):
        #for each topic, obtain the largest values, and add the words they map to into the dictionary.
        words_ids = model.components_[i].argsort()[:-no_top_words - 1:-1]
        words = [feature_names[key] for key in words_ids]
        word_dict['Topic # ' + '{:02d}'.format(i)] = words;
    dict = pd.DataFrame(word_dict);
    # dict.to_csv('%s.csv' % model_name)
    return dict

# run NMF
nmf_model = NMF(n_components=no_topics, random_state=1, l1_ratio=.5, init='nndsvd').fit(nmf_matrix)

# run LDA
lda_model = LatentDirichletAllocation(n_components= no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(lda_matrix)

# run LSA 
lsa_model = TruncatedSVD(n_components=no_topics, algorithm='randomized', n_iter=100, random_state=122).fit(lsa_matrix)

# %% [markdown]
# # 9. Display topics and top words
#
# Use display function to show the 10 topics generated by each model and their top words.

# %%
# display LDA topics and top words
display_topic(lda_model, lda_feature_names, no_topics, no_top_words, 'LDA_Model')
# Out:
# Model LDA_Model:
#      Topic # 00     Topic # 01      Topic # 02     Topic # 03  \
# 0       program          child            flow     accessible
# 1         using         design         express           user
# 2        design       learning  implementation        student
# 3         blind         torino            tree    environment
# 4      research    environment       guideline  accessibility
# 5    programmer  accessibility           focus          block
# 6    nonsighted      inclusive         sensory        include
# 7       student        ability         observe         create
# 8  auditory_cue     technology          number           tree
# 9      auditory         create      navigation          audio
#
#          Topic # 04   Topic # 05        Topic # 06        Topic # 07  \
# 0             blind        blind  sight_programmer     blind_student
# 1  blind_programmer      student             blind           barrier
# 2       participant   conclusion           reading        accessible
# 3     screen_reader    animation            syntax  computer_science
# 4  sight_programmer        audio             focus           learner
# 5             using      summary             study           project
# 6         challenge         lead           command       information
# 7              ides  methodology            method              need
# 8     accessibility       create              user          learning
# 9          software         game             using          research
#
#           Topic # 08            Topic # 09
# 0        development          auditory_cue
# 1              blind  programming_language
# 2           solution           participant
# 3        environment                result
# 4   blind_programmer              auditory
# 5  graphic_interface             spearcons
# 6           computer                future
# 7            problem                 blind
# 8           approach            programmer
# 9             usable      visuallyimpaired

# %%
# display LDA topics and top words
display_topic(lsa_model, lsa_feature_names, no_topics, no_top_words, 'LSA_Model')
# Out:
# Model LSA_Model:
#     Topic # 00     Topic # 01                  Topic # 02        Topic # 03  \
# 0        blind          child               blind_learner      auditory_cue
# 1       design         torino  audio_programming_language        nonsighted
# 2        child       learning                       skill          auditory
# 3  environment         design        novice_blind_learner  computer_program
# 4      program      inclusive               solve_problem          debugger
# 5      student  computational                     program     comprehension
# 6        using          story                    interact             debug
# 7     learning        teacher                  motivating           program
# 8   accessible        learner                    thinking        programmer
# 9         user       physical                        help               cue
#
#                         Topic # 04        Topic # 05         Topic # 06  \
# 0                          student     blind_student        participant
# 1                       accessible           barrier        source_code
# 2           blockbased_programming  computer_science              story
# 3                            block           project              audio
# 4                          blockly              data           navigate
# 5                             user              tree          structure
# 6                      environment        nonsighted             output
# 7                          library       information              block
# 8                        computing         interview              trial
# 9  blockbased_programming_language           program  novice_programmer
#
#                         Topic # 07        Topic # 08            Topic # 09
# 0                            story  sight_programmer              solution
# 1                            block    audiohighlight                  tree
# 2                 sight_programmer  blind_programmer             structure
# 3                            blind              area  description_language
# 4  blockbased_programming_language              tree                   aid
# 5                 blind_programmer           reading        audiohighlight
# 6                           output           barrier            nonsighted
# 7                         tangible              user     graphic_interface
# 8                             game         structure           development
# 9            blind_visually_impair        difference               include

# %%
# display LDA topics and top words
display_topic(nmf_model, nmf_feature_names, no_topics, no_top_words, 'NMF_Model')
# Out:
# Model NMF_Model:
#          Topic # 00     Topic # 01                  Topic # 02  \
# 0              code          child               blind_learner
# 1  blind_programmer       learning                 programming
# 2  sight_programmer         torino  audio_programming_language
# 3             blind         design                       skill
# 4          skimming      inclusive        novice_blind_learner
# 5              area  computational               solve_problem
# 6     screen_reader       physical                     learner
# 7           reading        ability                    interact
# 8       participant         vision                  motivating
# 9              tool        teacher                    thinking
#
#          Topic # 03              Topic # 04          Topic # 05  \
# 0      auditory_cue             environment           challenge
# 1        nonsighted  blockbased_programming  software_developer
# 2          auditory               computing     blind_developer
# 3  computer_program                    user           developer
# 4     comprehension           accessibility                face
# 5        programmer                 blockly          difficulty
# 6       source_code              accessible                ides
# 7          research                  design         participant
# 8           program         visually_impair            software
# 9          debugger                  impact                need
#
#          Topic # 06                       Topic # 07            Topic # 08  \
# 0     blind_student                            story              solution
# 1           barrier                            block           development
# 2  computer_science                       accessible                 blind
# 3           project  blockbased_programming_language                   aid
# 4            create                             game  description_language
# 5         interview                         tangible     graphic_interface
# 6              goal                           output           programming
# 7       information                          student      blind_programmer
# 8      dissertation                      programming                regard
# 9          overcome                            audio   graphical_interface
#
#   Topic # 09
# 0       tool
# 1  structure
# 2       tree
# 3    student
# 4    program
# 5      using
# 6       data
# 7  animation
# 8   strategy
# 9       user

# %% [markdown]
# # 10. Classify papers under topics
#
# Using the 10 topics generated by each of our models, we categorize each paper in our corpus under one of the 10 topics.

# %%
# use each model to assign topic to papers in corpus
lda_topic_values = lda_model.transform(lda_matrix)
nmf_topic_values = nmf_model.transform(nmf_matrix)
lsa_topic_values = lsa_model.transform(lsa_matrix)

# %%
lda_topic_values.argmax(axis=1)
# Out:
# array([3, 9, 3, 1, 7, 3, 0, 0, 0, 8, 0, 0, 0, 7, 3, 3, 0, 7, 4, 4, 4, 3,
#        3, 0, 1, 0, 4, 7, 0, 9, 0, 0, 1, 1, 3, 1, 3, 3, 4, 1, 0, 0, 0, 0,
#        8, 8, 9, 3, 4, 0])

# %%
dataset['LDA Topic'] = lda_topic_values.argmax(axis=1)
dataset['LSA Topic'] = lsa_topic_values.argmax(axis=1)
dataset['NMF Topic'] = nmf_topic_values.argmax(axis=1)
# dataset.to_csv('results.csv')
dataset.head(50)
# Out:
#                                                 Title  \
# 0   Design Considerations to Increase Block-based ...
# 1   Exploration of the use of auditory cues in cod...
# 2   Towards making block-based programming accessi...
# 3   Blocks4All: overcoming accessibility barriers ...
# 4   Making the Blockly Library Accessible via Touc...
# 5    Expanding Blocks4All with Variables and Funct...
# 6   An Accessible Blocks Language: Work in Progress.
# 7                      Nonvisual Visual Programming.
# 8   Accessible AST-Based Programming for Visually-...
# 9    Programming microworlds for visually impaired...
# 10         Blind learners programming through audio.
# 11  APL: audio programming language for blind lear...
# 12  Listen: A tool to investigate the use of sound...
# 13  Understanding and Improving Blind Students Acc...
# 14  To block or not to block, that is the question...
# 15  CodeTalk: Improving Programming Environment Ac...
# 16   On the design of an educational infrastructur...
# 17  Making Programming Accessible to Learners with...
# 18  Interviews and Observation of Blind Software D...
# 19  An exploratory study of blind software develop...
# 20  Eliciting Programming Challenges Faced by Deve...
# 21   Nonvisual tool for navigating hierarchical st...
# 22  StructJumper: A Tool to Help Blind Programmers...
# 23  Teaching data structures to students who are b...
# 24   Accessibility in introductory computer science.
# 25  An empirical investigation into the design of ...
# 26  An empirical study of blindness and program co...
# 27  Increasing access to computer science for blin...
# 28  Exploring auditory cues to locate code errors ...
# 29   An Initial Investigation into Non-visual Code...
# 30   A Java programming tool for students with vis...
# 31  On the design of program execution environment...
# 32  Torino: A tangible programming language inclus...
# 33  Physical Programming for Blind and Low Vision ...
# 34  Bonk: accessible programming for accessible au...
# 35  Enabling collaboration in learning computer pr...
# 36  StoryBlocks: A Tangible Programming Game To Cr...
# 37       Tangibles+ Programming+ Audio Stories= Fun.
# 38  A comparison of program comprehension strategi...
# 39  Physical Programming for Blind and Low Vision ...
# 40   WAD: A feasibility study using the wicked aud...
# 41                                         Sodbeans.
# 42                         Audio Aids in Source Code.
# 43  Tracking@ stemxcomet: teaching programming to ...
# 44      Making programming accessible to the blinds.
# 45  A new approach towards visual programming for ...
# 46  An exploratory study into the use of auditory ...
# 47  The architectural challenges of adding accessi...
# 48  AudioHighlight: Code Skimming for Blind Progra...
# 49  Tactile Code Skimmer: A Tool to Help Blind Pro...
#
#                                                 Codes  \
# 0                    BBL, DES, SR, KN, CE, CN, DT, CC
# 1                  AP, CN, CC, BBL, DES, DT, ACUE, SM
# 2                              BBL, DES, DT, WAPP, PC
# 3               BBL, CH, CN, CC, SR, TS, SM, KDG, MSH
# 4                            BBL, TS, SR, DES, CN, CE
# 5                          BBL,SR, TS, DES,  FUN, VAR
# 6                            BBL, KN, SR, NVP, PC, DT
# 7                     NVP, DES, KN, DFP, AP, SPCH, PC
# 8             SR, CN, CC, KN, DES, SM, TBL, BBL, WAPP
# 9                              TAN, AP, SPCH, SR, DES
# 10                                AP, DES, KN, CN, DT
# 11                                AP, DES, KN, CN, DT
# 12                                       ACUE, CD, PE
# 13                               CH, DES, CC, CN, TBP
# 14                                 BBL, HSH, TBP, LAR
# 15  CH, CD, DES, CC, CE, CN, KN, TBP, IDE, PRF, AC...
# 16  DES, ACUE, HSH, MSH, CH, SR, IDE, AT, CE, CC, ...
# 17                              AP, TBP, BBL, CN, TAN
# 18             CH, CN, SR, AT, LAR, PRF, IDE, TBP, DT
# 19                       CH, CN, SM, PRF, IDE, CO, FI
# 20                      CH, LAR, CN, CD, AT, PRF, IDE
# 21                                        CN, TL, IDE
# 22                   TBP, CN, CC, DT, SM, KN, IDE, SR
# 23                                    ACUE, SPCH, DES
# 24                                                TBP
# 25                    CC, ACUE, CD, SR, IDE, LAR, COL
# 26                                CC, SR, PRF, SM, KN
# 27                            TBP, CN, CC, DT, SM, DS
# 28                                      ACUE, CD, CN
# 29                   TBP, ACUE, DT, CC, SPCH, SM, PRF
# 30                      KN, TBP, TL, CN, CC, SPCH, DT
# 31               DES, CC, CN, CD, ACUE, PE, TL , TBP,
# 32                                 TAN, DES, SM, SPCH
# 33                              TAN, DES, PE, CO, LAR
# 34  CH, DES, HSH, TBP, SR, SPCH, OUT, SM, PC, DT, ...
# 35                             DES, TAN, SM, ACUE/OUT
# 36                        TAN, BBL, DES, LAR(16), OUT
# 37                                      TAN, DES, OUT
# 38                    CC, SR, TBP(JAVA), SM, PRF, FUN
# 39  (Repititive should be removed)TAN, DES, OUT, P...
# 40     TL, TBP,  CD, IDE, CC, ACUE, SPCH, PE, SM, COL
# 41                         CC, CD, TL, TBP, ACUE, IDE
# 42                              ACUE, CC, CN, SR, TBP
# 43                                           TAN, OUT
# 44                 CH,TBP, IDE, GUI (Not so relevant)
# 45                                   GUI, CH, AT, IDE
# 46            BBL, ACUES, SR, OUT, CN, SPCH,CTRL, FUN
# 47                                   DES, KN, BBL, CH
# 48           IDE, CN, FUN, CTRL, CC, SR, SM, PRF, TBP
# 49                      CN, TBP, CC, SR, TL, DES, TAN
#
#                                              Abstract  \
# 0   Block-based programming languages are a popula...
# 1   Visual programming languages are commonplace i...
# 2   Block-based programming environments are not a...
# 3   projects for pre-reader through grade 5 on the...
# 4   Block-based programming environments are a pop...
# 5   Blocks-based programming environments are ofte...
# 6   Block languages are extensively used to introd...
# 7   Visual programming systems are widely used to ...
# 8   Most programmers rely on visual tools (block-b...
# 9   The paper describes our research aimed at veri...
# 10  The development of programming skills is a mot...
# 11  Programming skills are strongly emphasized in ...
# 12  We describe the architecture and use of a tool...
# 13  Teaching people with disabilities tech skills ...
# 14   Blocks-based programming tools are becoming i...
# 15  In recent times, programming environments like...
# 16  The blind and visually impaired community is s...
# 17  Programming can be challenging to learn, and f...
# 18  Integrated Development Environments (IDEs) pla...
# 19  As a research community, we currently know ver...
# 20  Without understanding the programming difficul...
# 21  The hierarchical structure of a program can be...
# 22  It can be difficult for a blind developer to u...
# 23  We present our work in assisting students who ...
# 24  This paper describes our efforts to integrate ...
# 25  Decades of research have led to notable improv...
# 26  Blind programmers typically use a screen reade...
# 27  Computer science has many aspects that are ina...
# 28  The goal of my research is to support the work...
# 29  We investigate a novel, non-visual approach to...
# 30  This paper reports on a tool for assisting stu...
# 31  Comprehending and debugging computer programs ...
# 32  Across the world, policy initiatives are being...
# 33  There is a dearth of appropriate tools for you...
# 34  Introductory computer programming presents a n...
# 35  We investigate how technology can support coll...
# 36  Block-based programming languages can support ...
# 37  Block-based programming languages enable novic...
# 38  Programmers who are blind use a screen reader ...
# 39  There is a dearth of appropriate tools for you...
# 40  Contemporary programmers have a predominately ...
# 41  Comprehending and debugging computer programs ...
# 42  Source code makes use of a number of visual cu...
# 43  Introductory programming activities for studen...
# 44  Development of graphical interfaces and visual...
# 45  Visual user interfaces have left blind program...
# 46  Visual programming languages are commonly used...
# 47  Games take many forms, including educational e...
# 48  Blind programmers use a screen reader to read ...
# 49  Skimming new code with a screen reader can be ...
#
#                                            Conclusion  \
# 0   The initial version of accessible Blockly shou...
# 1                                       No conclusion
# 2                                       No conclusion
# 3   We conducted an evaluation of current blocks-b...
# 4   We present two interfaces which were designed ...
# 5   Our enhancements to Blocks4All have improved i...
# 6                                       No conclusion
# 7   Nonvisual visual programming is possible, and ...
# 8   While this evaluation focused exclusively on u...
# 9   Our environments are physical micro-worlds [11...
# 10  We have introduced APL, Audio Programming Lang...
# 11  We have introduced APL, Audio Programming Lang...
# 12  We have described a system named LISTEN design...
# 13  The overarching goal of my dissertation has be...
# 14  Blocks-based  programming  is  becoming  the  ...
# 15  We grouped the numerous accessibility challeng...
# 16  We are engaged in the first large-scale attemp...
# 17  Much of the research carried out in this space...
# 18  In this paper,  we presented our exploratory s...
# 19  In a series of interviews, we have explored th...
# 20  In this work, we explored the challenges faced...
# 21  The accessible tree navigation tool described ...
# 22  We created StructJumper, an Eclipse plugin tha...
# 23                                      No conclusion
# 24                                      No conclusion
# 25  This research makes three key contributions to...
# 26  In conclusion, we found that the blind and sig...
# 27                                      No conclusion
# 28                                      No conclusion
# 29  We have made a preliminary case for non-speech...
# 30  Our focus is on teaching students to learn how...
# 31  Non-sighted programmers face problems that the...
# 32  There is a strong diversity agenda behind the ...
# 33  The technologies that we design play a mediati...
# 34  We introduced Bonk, an accessible programming ...
# 35  We explored the design of the physical program...
# 36  As society increasingly recognizes the importa...
# 37  While block-based programming languages offer ...
# 38  Our conclusion is that blind and sighted progr...
# 39                                      No conclusion
# 40  In this paper, we have contributed in two prim...
# 41                                      No conclusion
# 42  This research has verified the effectiveness o...
# 43  Learning to program still presents many access...
# 44  Rapid development of GUI and programming tools...
# 45  Blinds have been using computers since the ver...
# 46  Our prototype demonstrates potential through i...
# 47                                      No conclusion
# 48  We have presented AudioHighlight, a code skimm...
# 49  We have presented TCS, a tactile tool to help ...
#
#                                            Paper_Text  \
# 0   Block-based programming languages are a popula...
# 1   Visual programming languages are commonplace i...
# 2   Block-based programming environments are not a...
# 3   projects for pre-reader through grade 5 on the...
# 4   Block-based programming environments are a pop...
# 5   Blocks-based programming environments are ofte...
# 6   Block languages are extensively used to introd...
# 7   Visual programming systems are widely used to ...
# 8   Most programmers rely on visual tools (block-b...
# 9   The paper describes our research aimed at veri...
# 10  The development of programming skills is a mot...
# 11  Programming skills are strongly emphasized in ...
# 12  We describe the architecture and use of a tool...
# 13  Teaching people with disabilities tech skills ...
# 14   Blocks-based programming tools are becoming i...
# 15  In recent times, programming environments like...
# 16  The blind and visually impaired community is s...
# 17  Programming can be challenging to learn, and f...
# 18  Integrated Development Environments (IDEs) pla...
# 19  As a research community, we currently know ver...
# 20  Without understanding the programming difficul...
# 21  The hierarchical structure of a program can be...
# 22  It can be difficult for a blind developer to u...
# 23  We present our work in assisting students who ...
# 24  This paper describes our efforts to integrate ...
# 25  Decades of research have led to notable improv...
# 26  Blind programmers typically use a screen reade...
# 27  Computer science has many aspects that are ina...
# 28  The goal of my research is to support the work...
# 29  We investigate a novel, non-visual approach to...
# 30  This paper reports on a tool for assisting stu...
# 31  Comprehending and debugging computer programs ...
# 32  Across the world, policy initiatives are being...
# 33  There is a dearth of appropriate tools for you...
# 34  Introductory computer programming presents a n...
# 35  We investigate how technology can support coll...
# 36  Block-based programming languages can support ...
# 37  Block-based programming languages enable novic...
# 38  Programmers who are blind use a screen reader ...
# 39  There is a dearth of appropriate tools for you...
# 40  Contemporary programmers have a predominately ...
# 41  Comprehending and debugging computer programs ...
# 42  Source code makes use of a number of visual cu...
# 43  Introductory programming activities for studen...
# 44  Development of graphical interfaces and visual...
# 45  Visual user interfaces have left blind program...
# 46  Visual programming languages are commonly used...
# 47  Games take many forms, including educational e...
# 48  Blind programmers use a screen reader to read ...
# 49  Skimming new code with a screen reader can be ...
#
#                                            clean_text  LDA Topic  LSA Topic  \
# 0   blockbased_programming_language popular means ...          3          0
# 1   visual programming_language commonplace engage...          9          6
# 2   blockbased_programming environment accessible ...          3          4
# 3   project prereader grade hour code blocksbased_...          1          0
# 4   blockbased_programming environment popular lea...          7          4
# 5   blocksbased_programming environment often inac...          3          0
# 6   block language extensively use introduce progr...          0          0
# 7   visual programming system widely use introduce...          0          0
# 8   programmer rely visual tool blockbased editor ...          0          0
# 9   paper_describe research aim verification suita...          8          0
# 10  development programming skill motivating issue...          0          2
# 11  programming skill strongly emphasize computer_...          0          2
# 12  describe architecture tool name listen general...          0          0
# 13  teaching people disability tech skill empower ...          7          5
# 14  blocksbased_programming tool become increasing...          3          0
# 15  recent times programming_environment like visu...          3          0
# 16  blind_visually_impair community significantly ...          0          0
# 17  programming challenge learn visually_impair le...          7          0
# 18  integrate development environment ides play im...          4          0
# 19  research community currently know little chall...          4          0
# 20  without understanding programming difficulty f...          4          0
# 21  hierarchical structure program quite complex m...          3          9
# 22  difficult blind_developer understand navigate ...          3          9
# 23  present work assist student blind understand f...          0          0
# 24  paper_describe effort integrate software acces...          1          0
# 25  decade research notable improvement representa...          0          3
# 26  blind_programmer typically screen_reader readi...          4          8
# 27  computer_science many aspect inaccessible some...          7          5
# 28  goal research support workflow programmer blin...          0          0
# 29  investigate novel nonvisual approach overviewi...          9          0
# 30  paper report tool assist student visual disabi...          0          0
# 31  comprehend debug computer_program difficult si...          0          3
# 32  across world policy initiative develop engage ...          1          1
# 33  dearth appropriate tool young learner mix visu...          1          1
# 34  introductory computer programming present numb...          3          0
# 35  investigate technology support collaborative l...          1          1
# 36  blockbased_programming_language support novice...          3          0
# 37  blockbased_programming_language enable novice_...          3          7
# 38  programmer blind screen_reader speak source_co...          4          8
# 39  dearth appropriate tool young learner mix visu...          1          1
# 40  contemporary programmer predominately visual e...          0          0
# 41  comprehend debug computer_program inherently d...          0          3
# 42  source_code make number visual cue convey info...          0          0
# 43  introductory_programming activity student ofte...          0          0
# 44  development graphical_interface visual program...          8          9
# 45  visual interface left blind_programmer able pe...          8          9
# 46  visual programming_language commonly use help ...          9          0
# 47  game take many form include educational enviro...          3          0
# 48  blind_programmer screen_reader read code aloud...          4          8
# 49  skimming code screen_reader timeconsuming task...          0          0
#
#     NMF Topic
# 0           4
# 1           3
# 2           4
# 3           4
# 4           4
# 5           4
# 6           7
# 7           2
# 8           9
# 9           1
# 10          2
# 11          2
# 12          9
# 13          6
# 14          9
# 15          5
# 16          6
# 17          1
# 18          5
# 19          5
# 20          5
# 21          9
# 22          9
# 23          9
# 24          6
# 25          3
# 26          0
# 27          6
# 28          3
# 29          3
# 30          9
# 31          3
# 32          1
# 33          1
# 34          7
# 35          1
# 36          7
# 37          7
# 38          0
# 39          1
# 40          3
# 41          3
# 42          3
# 43          6
# 44          8
# 45          8
# 46          3
# 47          4
# 48          0
# 49          0
